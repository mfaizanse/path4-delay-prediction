# %%
import mvg_api
import json

# %%
stationId = mvg_api.get_id_for_station('Ostbahnhof')
print(stationId)
# Out:
# 5

# %%
departures = mvg_api.get_departures(stationId)
# print(departures)
print(json.dumps(departures, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "departureId": 357703107,
#         "departureTime": 1562166870000,
#         "departureTimeMinutes": 0,
#         "destination": "Hauptbahnhof Nord",
#         "label": "100",
#         "lineBackgroundColor": "#0d5c70",
#         "live": true,
#         "product": "BUS",
#         "sev": false
#     },
#     {
#         "departureId": 2002342222,
#         "departureTime": 1562166888000,
#         "departureTimeMinutes": 0,
#         "destination": "Neuperlach S\u00fcd",
#         "label": "U5",
#         "lineBackgroundColor": "#b78730",
#         "live": true,
#         "product": "UBAHN",
#         "sev": false
#     },
#     {
#         "departureId": -960906613,
#         "departureTime": 1562166896000,
#         "departureTimeMinutes": 0,
#         "destination": "Laimer Platz",
#         "label": "U5",
#         "lineBackgroundColor": "#b78730",
#         "live": true,
#         "product": "UBAHN",
#         "sev": false
#     },
#     {
# ...
